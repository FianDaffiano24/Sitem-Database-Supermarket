# %% [markdown]
# <a href="https://colab.research.google.com/github/FianDaffiano24/Sitem-Database-Supermarket/blob/main/Copy_of_EDA_games_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exploratory Data Analysis Using Games Sales Repository Data**
#
# by : Muhammad Daffiano Rahmatullah (Fian)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data_link = 'https://docs.google.com/spreadsheets/d/1z46qH9il8OfVkYBZMMDUYq_GYHp77_prgkKq6HysZts/edit#gid=1485085913'
# data_link_trf = data_link.replace('/edit#gid=', '/export?format=csv&gid=')
# print(data_link_trf)
# df = pd.read_csv(data_link_trf)
# df

# %%
# df['Release'] = pd.to_datetime(df['Release'])
# df = df.drop_duplicates()
# print(df.info())
# df

# %%
data_link = 'https://docs.google.com/spreadsheets/d/1z46qH9il8OfVkYBZMMDUYq_GYHp77_prgkKq6HysZts/edit#gid=1485085913'
data_link_trf = data_link.replace('/edit#gid=', '/export?format=csv&gid=')
df = pd.read_csv(data_link_trf)
df
# Out:
#                                      Name  Sales          Series    Release  \
# 0           PlayerUnknown's Battlegrounds   42.0             NaN  12/1/2017
# 1                               Minecraft   33.0       Minecraft  11/1/2011
# 2                              Diablo III   20.0          Diablo   5/1/2012
# 3                             Garry's Mod   20.0             NaN  11/1/2006
# 4                                Terraria   17.2             NaN   5/1/2011
# ..                                    ...    ...             ...        ...
# 172        Who Wants to Be a Millionaire?    1.0             NaN  11/1/1999
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander  12/1/1994
# 174                            Zoo Tycoon    1.0      Zoo Tycoon  10/1/2001
# 175      StarCraft II: Heart of the Swarm    1.0       StarCraft   3/1/2013
# 176      StarCraft II: Legacy of the Void    1.0       StarCraft  11/1/2015
#
#                        Genre               Developer  \
# ...

# %%
df_cleaned = df.copy()
df_cleaned['Release'] = pd.to_datetime(df['Release'])
df_cleaned['Release']
# Out:
# 0     2017-12-01
# 1     2011-11-01
# 2     2012-05-01
# 3     2006-11-01
# 4     2011-05-01
#          ...
# 172   1999-11-01
# 173   1994-12-01
# 174   2001-10-01
# 175   2013-03-01
# 176   2015-11-01
# Name: Release, Length: 177, dtype: datetime64[ns]

# %%
df_cleaned = df.drop_duplicates()
df_cleaned
# Out:
#                                      Name  Sales          Series    Release  \
# 0           PlayerUnknown's Battlegrounds   42.0             NaN  12/1/2017
# 1                               Minecraft   33.0       Minecraft  11/1/2011
# 2                              Diablo III   20.0          Diablo   5/1/2012
# 3                             Garry's Mod   20.0             NaN  11/1/2006
# 4                                Terraria   17.2             NaN   5/1/2011
# ..                                    ...    ...             ...        ...
# 170                              Vietcong    1.0        Vietcong   3/1/2003
# 171    Warhammer Online: Age of Reckoning    1.0       Warhammer   9/1/2008
# 172        Who Wants to Be a Millionaire?    1.0             NaN  11/1/1999
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander  12/1/1994
# 174                            Zoo Tycoon    1.0      Zoo Tycoon  10/1/2001
#
#                        Genre               Developer  \
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       177 non-null    object
#  1   Sales      177 non-null    float64
#  2   Series     141 non-null    object
#  3   Release    177 non-null    datetime64[ns]
#  4   Genre      177 non-null    object
#  5   Developer  177 non-null    object
#  6   Publisher  177 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 9.8+ KB

# %%
df_cleaned.columns
# Out:
# Index(['Name', 'Sales', 'Series', 'Release', 'Genre', 'Developer',
#        'Publisher'],
#       dtype='object')

# %%
for x in ['Name', 'Sales', 'Series', 'Release', 'Genre', 'Developer',
       'Publisher']:
       print(df_cleaned[x].value_counts(), '/n')
# Out:
# StarCraft II: Heart of the Swarm    2
# StarCraft II: Legacy of the Void    2
# PlayerUnknown's Battlegrounds       1
# Duke Nukem 3D                       1
# Crysis Warhead                      1
#                                    ..
# Battlefield 1942                    1
# Black & White                       1
# Civilization III                    1
# Cossacks II: Napoleonic Wars        1
# Zoo Tycoon                          1
# Name: Name, Length: 175, dtype: int64 /n
# 1.0     79
# 2.0     33
# 3.0      9
# 4.0      7
# 2.5      5
# 1.5      4
# 6.0      4
# 5.0      4
# 1.3      3
# 20.0     2
# 5.5      2
# 1.1      2
# 1.2      2
# 9.0      2
# 10.0     2
# 11.0     2
# 12.0     2
# 2.7      1
# 2.1      1
# 1.8      1
# 42.0     1
# 3.3      1
# 3.6      1
# 33.0     1
# 6.5      1
# 7.0      1
# 8.0      1
# 14.0     1
# 17.2     1
# 4.5      1
# Name: Sales, dtype: int64 /n
# StarCraft                6
# Command & Conquer        5
# Civilization             4
# ...

# %%
#download dataset clean
df_cleaned.to_csv('games_sales_cleaned.csv')

# %% [markdown]
# EDA

# %%
#game lama
gameoldtonew = df_cleaned.sort_values(by='Release')
df_gameoldtonew = gameoldtonew[['Name', 'Release']]
df_gameoldtonew.head(5)
# Out:
#                                        Name    Release
# 133                                 Hydlide 1984-12-01
# 34   Where in the World Is Carmen Sandiego? 1985-06-01
# 88                     International Karate 1985-11-01
# 162                                  Tetris 1988-01-01
# 22                             Last Ninja 2 1988-08-01

# %%
#game baru
df_cleaned[['Name', 'Release']].sort_values('Release', ascending=False).head(5)
# Out:
#                    Name    Release
# 20              Valheim 2021-02-01
# 27       Cyberpunk 2077 2020-12-01
# 110  Crusader Kings III 2020-09-01
# 10            Fall Guys 2020-08-01
# 139             Mordhau 2019-04-01

# %%
#publisher terbanyak berdasarkan game
# publisher = (df_cleaned.groupby(by=['Publisher'])['Name']
#        .count()
#        .sort_values(ascending=False)
#        .reset_index(name='Jumlah game')
#        )
# publisher.head()
publisher = df_cleaned.groupby(['Publisher'], as_index=False)['Name'].count()
publisher.sort_values('Name', ascending=False).head(5)
# Out:
#                  Publisher  Name
# 28         Electronic Arts    19
# 8   Blizzard Entertainment     8
# 62     Paradox Interactive     7
# 2               Activision     6
# 37          GT Interactive     5

# %%
publish = df_cleaned.groupby('Publisher', as_index=False)['Name'].nunique()
publish.sort_values('Name', ascending=False).head(5)
# Out:
#                  Publisher  Name
# 28         Electronic Arts    19
# 8   Blizzard Entertainment     8
# 62     Paradox Interactive     7
# 2               Activision     6
# 37          GT Interactive     5

# %%
plt.figure(figsize=(18,8))
plt.bar('Publisher', 'Name', data=publish)
plt.xlabel('Publisher', size=16)
plt.ylabel('Jumlah game', size=14)
plt.show()

# %%
developer = (df_cleaned.groupby(by=['Developer'])['Name']
             .count()
             .sort_values(ascending=False)
             .reset_index(name='Banyak_game'))
developer.head(5)
# developer = df_cleaned.groupby(['Developer'], as_index=False)['Name'].count()
# developer.sort_values('Name', ascending=False).head(5)
# Out:
#                     Developer  Banyak_game
# 0      Blizzard Entertainment           10
# 1                       Maxis            6
# 2  Paradox Development Studio            5
# 3                 id Software            4
# 4            Westwood Studios            4

# %%
plt.rcParams["figure.figsize"] = (10,5)
sns.barplot('Pub', 'Invoice ID', data = agg_payment.sort_values('Invoice ID', ascending=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-29e187d00cfb> in <cell line: 2>()
#       1 plt.rcParams["figure.figsize"] = (10,5)
# ----> 2 sns.barplot('Developer', 'Name', data = developer.sort_values('Name', ascending=False))
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
# ...

# %%
#series yang memiliki jumlah sales terbanyak
games_sales = (df_cleaned.groupby(by=['Series'])['Sales']
       .sum()
       .sort_values(ascending=False)
       .reset_index(name='Jumlah Sales'))
games_sales.head(5)
# Out:
#       Series  Jumlah Sales
# 0  Minecraft          33.0
# 1     Diablo          26.0
# 2   The Sims          24.0
# 3  Half-Life          21.0
# 4  StarCraft          21.0

# %%
#series yang merilis game terbanyak
series_game = (df_cleaned.groupby(by=['Series'])['Name']
       .count()
       .sort_values(ascending=False)
       .reset_index(name='banyak game'))
series_game.head(5)
# Out:
#               Series  banyak game
# 0          StarCraft            6
# 1  Command & Conquer            5
# 2     Age of Empires            4
# 3       Civilization            4
# 4         Dark Souls            3
